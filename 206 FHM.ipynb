# %%
print("Operadores Matematicos")
print("Realiza la suma 4 + 4 =" , 4 + 4)
print("Realiza la resta de 8 - 6" , 8 - 6)

operadores Matematicos
Realiza la suma 4 + 4 = 8
Realiza la resta de 8 - 6 = 2

# %%
print("Operadores Matematicos")
print("Realiza la suma 5 + 5 =" , 5 + 5)
print("Realiza la suma de 6 + 10 =" , 6 + 10)
print("Realiza la suma de 44 + 3 =" , 44 + 3)
print("Realiza la suma de 50 + 55 =" , 50 + 55)
print("Realiza la suma de 70 + 20 =" , 70 + 20)
print("Realiza la suma de 40 + 30 =" , 40 + 30)
print("Realiza la suma de 3 + 20 =" , 3 + 20)
print("Realiza la suma de 5 + 10 =" , 5 + 15)
print("Realiza la suma de 30 + 25 =" , 30 + 25)
print("Realiza la suma de 80 + 10 =" , 80 + 10)
# Out:
# Operadores Matematicos
# Realiza la suma 5 + 5 = 10
# Realiza la suma de 6 + 10 = 16
# Realiza la suma de 44 + 3 = 47
# Realiza la suma de 50 + 55 = 105
# Realiza la suma de 70 + 20 = 90
# Realiza la suma de 40 + 30 = 70
# Realiza la suma de 3 + 20 = 23
# Realiza la suma de 5 + 10 = 20
# Realiza la suma de 30 + 25 = 55
# Realiza la suma de 80 + 10 = 90

# %%
print("Operadores Matematicos")
print("Realiza la resta 25 - 10 =" , 25 - 10)
print("Realiza la resta 50 - 25 =" , 50 - 25)
print("Realiza la resta 30 - 15 =" , 30 - 15)
print("Realiza la resta 50 - 40 =" , 50 - 40)
print("Realiza la resta 55 - 15 =" , 55 - 15)
print("Realiza la resta 22 - 11 =" , 22 - 11)
print("Realiza la resta 500 - 250 =" , 500 - 250)
print("Realiza la resta 300 - 150 =" , 300 - 150)
print("Realiza la resta 800 - 400 =" , 800 - 400)
print("Realiza la resta 500 - 354 =" , 500 - 354)
# Out:
# Operadores Matematicos
# Realiza la resta 25 - 10 = 15
# Realiza la resta 50 - 25 = 25
# Realiza la resta 30 - 15 = 15
# Realiza la resta 50 - 40 = 10
# Realiza la resta 55 - 15 = 40
# Realiza la resta 22 - 11 = 11
# Realiza la resta 500 - 250 = 250
# Realiza la resta 300 - 150 = 150
# Realiza la resta 800 - 400 = 400
# Realiza la resta 500 - 354 = 146

# %%
print("Operadores Matematicos")
print("Realiza la multiplicacion 5 * 9 =" , 5 * 9)
print("Realiza la multiplicacion 5 * 4 =" , 5 * 4)
print("Realiza la multiplicacion 6 * 9 =" , 6 * 9)
print("Realiza la multiplicacion 7 * 3 =" , 7 * 3)
print("Realiza la multiplicacion 4 * 9 =" , 4 * 9)
print("Realiza la multiplicacion 5 * 5 =" , 5 * 5)
print("Realiza la multiplicacion 33 * 44 =" , 33 * 44)
print("Realiza la multiplicacion 55 * 23 =" , 55 * 23)
print("Realiza la multiplicacion 60 * 2 =" , 60 * 2)
print("Realiza la multiplicacion 25 * 33 =" , 25 * 33)
# Out:
# Operadores Matematicos
# Realiza la multiplicacion 5 * 9 = 45
# Realiza la multiplicacion 5 * 4 = 20
# Realiza la multiplicacion 6 * 9 = 54
# Realiza la multiplicacion 7 * 3 = 21
# Realiza la multiplicacion 4 * 9 = 36
# Realiza la multiplicacion 5 * 5 = 25
# Realiza la multiplicacion 33 * 44 = 1452
# Realiza la multiplicacion 55 * 23 = 1265
# Realiza la multiplicacion 60 * 2 = 120
# Realiza la multiplicacion 25 * 33 = 825

# %%
print("Operadores Matematicos")
print("Realiza la divicion 300 / 4 =" , 300 / 4)
print("Realiza la divicion 550 / 6 =" , 550 / 6)
print("Realiza la divicion 603 / 4 =" , 603 / 4)
print("Realiza la divicion 284 / 5 =" , 284 / 5)
print("Realiza la divicion 584 / 2 =" , 584 / 2)
print("Realiza la divicion 99 / 3 =" , 99 / 3)
print("Realiza la divicion 10 / 2 =" , 10 / 2)
print("Realiza la divicion 77 / 6 =" , 77 / 6)
print("Realiza la divicion 56 / 8 =" , 56 / 8)
print("Realiza la divicion 44 / 2 =" , 44 / 2)
# Out:
# Operadores Matematicos
# Realiza la divicion 300 / 4 = 75.0
# Realiza la divicion 550 / 6 = 91.66666666666667
# Realiza la divicion 603 / 4 = 150.75
# Realiza la divicion 284 / 5 = 56.8
# Realiza la divicion 584 / 2 = 292.0
# Realiza la divicion 99 / 3 = 33.0
# Realiza la divicion 10 / 2 = 5.0
# Realiza la divicion 77 / 6 = 12.833333333333334
# Realiza la divicion 56 / 8 = 7.0
# Realiza la divicion 44 / 2 = 22.0

# %%
print("Realiza la multiplicacion de 5 * 4" , 4 + 4)

Realiza la multiplicacion 5 * 4 = 20
